# %%
#Find predicted income in year 2020.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv(r'C:\Users\USER\Downloads\canada_per_capita_income.csv')
df.head(10)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583
# 5  1975              5998.144346
# 6  1976              7062.131392
# 7  1977              7100.126170
# 8  1978              7247.967035
# 9  1979              7602.912681

# %%
# %matplotlib inline
plt.xlabel('year', fontsize=20)
plt.ylabel('income(US)', fontsize=20)
plt.suptitle('ASSIGNMENT1')
plt.grid()
plt.scatter(df.year, df['per capita income (US$)'], marker= 'D', color='green')
plt.plot(df.year, reg.predict(df[['year']]), color='purple')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       5 plt.grid()
#       6 plt.scatter(df.year, df['per capita income (US$)'], marker= 'D', color='green')
# ----> 7 plt.plot(df.year, reg.predict(df[['year']]), color='purple')
#
# NameError: name 'reg' is not defined

# %%
model=LinearRegression()
model.fit(df[['year']], df['per capita income (US$)'])
model.predict([[2020]])
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
model.coef_
# Out:
# array([828.46507522])

# %%
model.intercept_
# Out:
# -1632210.7578554575

# %%
# SAVING TRAINED MODEL USING PICKLE

# %%
import pickle

# %%
with open('model_pickle', 'wb') as f:
    pickle.dump(model, f)

# %%
with open('model_pickle', 'rb') as f:
    mp = pickle.load(f)

# %%
mp.predict([[2019]])
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([40460.22901919])

# %%
# using sklearn joblib

# %%
import joblib

# %%
joblib.dump(model, 'model_joblib')
# Out:
# ['model_joblib']

# %%
mj = joblib.load('model_joblib')

# %%
mj.predict([[2019]])
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([40460.22901919])
