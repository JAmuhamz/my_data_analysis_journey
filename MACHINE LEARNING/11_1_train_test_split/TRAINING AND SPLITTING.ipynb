# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\USER\Downloads\carprices2.csv')
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          29400
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          20000
# 11    79000         7          21000
# 12    59000         5          33000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# MILLEAGE VS SELL PRICE

# %%
plt.xlabel('SELLPRICE')
plt.ylabel('MILEAGE')
plt.scatter(df['Mileage'], df['Sell Price($)'], color='blue' )

# %% [markdown]
# AGE VS SELL PRICE

# %%
plt.xlabel('SELLPRICE')
plt.ylabel('AGE')
plt.scatter(df['Age(yrs)'], df['Sell Price($)'], color='red' )

# %%
x=df[['Mileage', 'Age(yrs)']]
x
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5

# %%
y=df['Sell Price($)']
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=10)

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 6     52000         5
# 8     91000         8
# 2     57000         5
# 12    59000         5
# 5     59000         5
# 10    83000         7
# 1     35000         3
# 0     69000         6
# 4     46000         4
# 9     67000         6

# %%
x_test
# Out:
#     Mileage  Age(yrs)
# 3     22500         2
# 7     72000         6
# 11    79000         7

# %%
from sklearn.linear_model import LinearRegression

# %%
clf=LinearRegression()

# %%
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
clf.score(x_test, y_test)
# Out:
# 0.9224816911971745

# %%
clf.predict(x_test)
# Out:
# array([41842.49106079, 22531.68057211, 18423.93325387])

# %%
y_test
# Out:
# 3     40000
# 7     19300
# 11    21000
# Name: Sell Price($), dtype: int64
